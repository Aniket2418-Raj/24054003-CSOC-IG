# %% [markdown]
# <a href="https://colab.research.google.com/github/Aniket2418-Raj/24054003-CSOC-IG/blob/main/Scikit_learn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Plan of Attack**

# %% [markdown]
# So here we have learnt algo, metrices, preprocesing, model-selection, pipelines

# %% [markdown]
# ***Sklearn Transformers***

# %% [markdown]
# **Estimators**

# %% [markdown]
# In scikit-learn, an estimator is any object that learns from data.
# It follows a consistent API, which makes models, preprocessors, and pipelines easy to swap and combine.
#
# It is also called fit method.
# It is two types:-
#
# 1. Predictors [predict() function will be there ]
# 2. Transformers [ Here transform/ fit-transform will be there]

# %% [markdown]
# Predictors are two types :
#
# 1. Regression
#
# 2. Classifiaction
