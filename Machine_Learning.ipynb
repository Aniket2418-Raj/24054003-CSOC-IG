# %% [markdown]
# <a href="https://colab.research.google.com/github/Aniket2418-Raj/24054003-CSOC-IG/blob/main/Machine_Learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Pandas Profiling**

# %%
# !pip install ydata-profiling

# %%
import pandas as pd
df=pd.read_csv('/content/Titanic-Dataset.csv')
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
import pandas as pd
import numpy as np

from ydata_profiling import ProfileReport
prof = ProfileReport(df)
prof.to_file(output_file='output.html')
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %% [markdown]
# **Feature Engineering**

# %% [markdown]
# Feature engineering is the process of using domain knowledge to extract features from raw data. These featues can be used to improve the performance of ML algos

# %% [markdown]
# We can devide feature engineering in 4 types:-
#
#
# 1.   Feature Selection
# 2.   Feature Construction
# 3.   Feature extraction
# 4.   Feature Transformation

# %% [markdown]
# we can devide Feature Transformation in 4 types:-
#
# 1.  Missing value Imputation
# 2.  Handling Categorical Features
# 3.  Outlier Detection
# 4.  Feature Scaling

# %% [markdown]
# **Feature Scaling**:
#
# It is a technique to standardize the independent features present in the data in a fixed range.
#
# It is two types :-
#
# 1.Standardization.
#
# 2.Normalization.

# %% [markdown]
# Standardization is also ***Called Z-score Normalization***.Here we do mainly two things
#
# 1.mean centering.
#
# 2.Scaling by the factor of S.D

# %% [markdown]
# ![zscore formula.gif](data:image/gif;base64,...)

# %% [markdown]
# Now from a data set of values x1,x2,x3,...we will get z1,z2,z3.... So now the new data set z1,z2,z3... is ready and the ***their mean will be 0*** && their ***Standard Devation will be 1***.

# %% [markdown]
# **When to use Standarization**

# %% [markdown]
# ![use of standarisation.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# **Normalization**

# %% [markdown]
# It is a technique often applied as part of data preparation for machine learning .The goal of normalization is to change the values of numeric columns in the dataset to use a common scale, without distorting differences in the ranges of values or losing information.

# %% [markdown]
# It is 4 types :-
#
# 1.Min-Max Scaling.
#
# 2.Mean Normalization.
#
# 3.Max Absolute .
#
# 4.Robust Scaling.

# %% [markdown]
# 1. Min-Max Scaling
#
# ![Min-max formula.png](data:image/png;base64,...)

# %% [markdown]
# 2.Mean- Max Normalization
#
# ![Mean-max.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# Here mean(x) will come in top instade of min(x).Here we get value in range of -1 to 1.

# %% [markdown]
# 3. Max Absolute scaling

# %% [markdown]
# ![Max absolute scaling.png](data:image/png;base64,...)

# %% [markdown]
# 4. Robust Scaling

# %% [markdown]
# ![Robust.png](data:image/png;base64,...)

# %% [markdown]
# ![IQR.png](data:image/png;base64,...)

# %% [markdown]
# Here it is ***best data which has outliers***

# %% [markdown]
# **Encoding Categorical Variables**

# %% [markdown]
# Data is two types frirst is ***nominal ***and second is*** ordinal.***
#
# Here nominal datas are unstructed data like states.
#
# Ordinal datas are structed data like first class, second calss etc

# %% [markdown]
# So encoding is two types :-
#
# 1. Nominal encoding
#
# 2. One Hot encoding

# %% [markdown]
# **Label** **Encoding**

# %% [markdown]
# **Ordinal Encoding**

# %% [markdown]
# Let's suppose we have some data about studnts of HS, UG and PG .Now if we give value 2 to the PG , 1 to the UG and 0 to the HS. Then ordinal encoding term will do autometically.
